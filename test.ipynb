# %% [markdown]
# # My Jupyter Notebook on 'IBM Watson Studio'

# %% [markdown]
# **PAVAN SHANKAR**
#
# I want to become a "Data Scientist"

# %% [markdown]
# *I'm passionate about 'data science' because we can do wonders using data and big data, for example using data analytics 'Golden State Warriors' won NBA League in 2009*

# %% [markdown]
# ### Listing of names

# %%
['Pinto', 'Tucker', 'Krish']
# Out:
# ['Pinto', 'Tucker', 'Krish']

# %% [markdown]
# > Food and Beverages
#
# <ol>
#     <li>Pasta</li>
#     <li>burger</li>
#     <li>cake</li>
# </ol>
# _____
#
# <ul>
#     <li>coke</li>
#     <li>beer</li>
#     <li>mocktail</li>
# </ul>
#
# To order click on this ["Hardrock Cafe"](https://www.hardrockcafe.com/)
# >>menu
#
# |food||beverages|
# | ------------- |:-------------:|-------|
# |pasta||coke|
# |Burger||beer|
# |cake||mocktail|

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# ![download%20jpg%201.jfif](attachment:download%20jpg%201.jfif)

# %% [markdown]
# ![download%20%284%29.jfif](attachment:download%20%284%29.jfif)

# %% [markdown]
# ![download.jpg2.jpg](attachment:download.jpg2.jpg)

# %% [markdown]
# ![download%20%2815%29.jfif](attachment:download%20%2815%29.jfif)

# %% [markdown]
# ![download%20%2816%29.jfif](attachment:download%20%2816%29.jfif)
